# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %%
rows = []

def parse_beer(beer):
    return [beer.get('id'),
            beer.get('name'), 
            beer.get('abv'), 
            beer.get('ibu', 0),
            beer.get('originalGravity'),
            beer.get('style',{}).get('ogMin'),
            beer.get('isOrganic'),
            beer.get('style', {}).get('categoryId'),
            beer.get('style', {}).get('category', {}).get('name'),
            beer.get('styleId'),
            beer.get('style', {}).get('name'),
            beer.get('style', {}).get('description'),
            beer.get('servingTemperatureDisplay'),
            beer.get('foodPairings'),
            beer.get('description'),
            beer.get('labels', {}).get('medium'),
            beer.get('glasswareId'),
            beer.get('glass', {}).get('name'),
            beer.get('srmId'),
            beer.get('srm', {}).get('hex'),
            beer.get('style', {}).get('srmMin'),
            beer.get('style', {}).get('srmMax')
           ]


ibus = range(80,150)
for ibu in ibus:
    if ibu % 2 == 0:
        print ibu
        pd.DataFrame(rows).to_csv('saved_beers.csv', encoding='utf-8')
    r = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p=1&ibu='+str(ibu))
    response = r.json()
    rows += [parse_beer(r) for r in response['data']]
    if response['numberOfPages'] > 1:
        page = range(2,response['numberOfPages']+1)
        for p in page:
            response = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p='+str(p)+'&ibu='+str(ibu)).json()
            rows += [parse_beer(r) for r in response['data']]
# Out:
# 80
# 82
# 84
# 86
# 88
# 90
# 92
# 94
# 96
# 98
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 128
# KeyErrorTraceback (most recent call last)
# <ipython-input-28-5884a0dc4e4e> in <module>()
#      34     r = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p=1&ibu='+str(ibu))
#      35     response = r.json()
# ---> 36     rows += [parse_beer(r) for r in response['data']]
#      37     if response['numberOfPages'] > 1:
#      38         page = range(2,response['numberOfPages']+1)
#
# KeyError: 'data'

# %%
beers = pd.DataFrame(rows)
beers.head()
# Out:
#        0                                1     2   3      4      5  6    7   \
# 0  wRmmdv     "California Crude" Black IPA   7.6  80   None  1.056  N  3.0
# 1  TAtY2B        "Sneaky Devil" Double IPA   7.8  80   None  1.075  N  3.0
# 2  2toTiw                            # 100    10  80  1.094   1.03  N  1.0
# 3  btwcy1             077XX India Pale Ale   7.8  80   None  1.075  N  3.0
# 4  KGBlvK  100 Barrel Series #4 Barleywine  10.3  80   None   1.09  N  3.0
#
#                            8     9  ...                      12    13  \
# 0  North American Origin Ales  41.0 ...                    None  None
# 1  North American Origin Ales  31.0 ...                    None  None
# 2         British Origin Ales   7.0 ...  Warm - (14-16C/57-61F)  None
# 3  North American Origin Ales  31.0 ...                    None  None
# 4  North American Origin Ales  34.0 ...                    None  None
#
#                                                   14  \
# 0  Black ale that is aggressively hopped to balan...
# 1  A light golden double-IPA with plenty of body ...
# 2  Our 100th batch, brewed for the enjoyment of t...
# 3  Like all things truly Jersey, 077XX makes the ...
# 4  Our Barleywine pours a reddish, golden hue wit...
#
#                                                   15   16       17   18  \
# 0                                               None  NaN     None  NaN
# 1                                               None  6.0  Snifter  NaN
# 2                                               None  NaN     None  NaN
# 3  https://s3.amazonaws.com/brewerydbapi/beer/btw...  5.0     Pint  5.0
# 4                                               None  NaN     None  NaN
#
#        19  20  21
# 0    None  35  35
# 1    None   5  13
# 2    None   8  17
# 3  FBB123   5  13
# 4    None  11  22
#
# [5 rows x 22 columns]

# %%
beers.isnull().sum()
# Out:
# 0        0
# 1        0
# 2       23
# 3        0
# 4     1546
# 5       77
# 6        0
# 7        3
# 8        3
# 9        3
# 10       3
# 11       3
# 12    1654
# 13    1678
# 14     357
# 15     941
# 16    1179
# 17    1179
# 18    1420
# 19    1420
# 20      73
# 21      77
# dtype: int64

# %%
beers.shape
# Out:
# (1840, 22)

# %%
beer_list = pd.read_csv('beers_redux2.csv')

# %%
beer_list.columns = ['unknown',
                     'id',
                     'name',
                     'abv',
                     'ibu',
                     'originalGravity',
                     'ogMin',
                     'isOrganic',
                     'categoryId',
                     'category_name',
                     'styleId',
                     'style_name',
                     'style_description',
                     'servingTemperature',
                     'foodPairings',
                     'beer_description',
                     'labels',
                     'glasswareId',
                     'glass_name',
                     'srmId',
                     'srm_hex',
                     'srmMin',
                     'srmMax'
                     ]
beer_list.head()
# Out:
#    unknown      id                             name   abv  ibu  \
# 0        0  wRmmdv     "California Crude" Black IPA   7.6   80
# 1        1  TAtY2B        "Sneaky Devil" Double IPA   7.8   80
# 2        2  2toTiw                            # 100  10.0   80
# 3        3  btwcy1             077XX India Pale Ale   7.8   80
# 4        4  KGBlvK  100 Barrel Series #4 Barleywine  10.3   80
#
#    originalGravity  ogMin isOrganic  categoryId               category_name  \
# 0              NaN  1.056         N         3.0  North American Origin Ales
# 1              NaN  1.075         N         3.0  North American Origin Ales
# 2            1.094  1.030         N         1.0         British Origin Ales
# 3              NaN  1.075         N         3.0  North American Origin Ales
# 4              NaN  1.090         N         3.0  North American Origin Ales
#
#     ...        servingTemperature foodPairings  \
# 0   ...                       NaN          NaN
# 1   ...                       NaN          NaN
# 2   ...    Warm - (14-16C/57-61F)          NaN
# 3   ...                       NaN          NaN
# 4   ...                       NaN          NaN
#
#                                     beer_description  \
# 0  Black ale that is aggressively hopped to balan...
# 1  A light golden double-IPA with plenty of body ...
# 2  Our 100th batch, brewed for the enjoyment of t...
# 3  Like all things truly Jersey, 077XX makes the ...
# 4  Our Barleywine pours a reddish, golden hue wit...
#
#                                               labels glasswareId glass_name  \
# 0                                                NaN         NaN        NaN
# 1                                                NaN         6.0    Snifter
# 2                                                NaN         NaN        NaN
# 3  https://s3.amazonaws.com/brewerydbapi/beer/btw...         5.0       Pint
# 4                                                NaN         NaN        NaN
#
#   srmId  srm_hex srmMin  srmMax
# 0   NaN      NaN   35.0    35.0
# 1   NaN      NaN    5.0    13.0
# 2   NaN      NaN    8.0    17.0
# 3   5.0   FBB123    5.0    13.0
# 4   NaN      NaN   11.0    22.0
#
# [5 rows x 23 columns]

# %%
beer_list.isnull().sum()
# Out:
# unknown                  0
# id                       0
# name                     0
# abv                     23
# ibu                      0
# originalGravity       1545
# ogMin                   77
# isOrganic                0
# categoryId               3
# category_name            3
# styleId                  3
# style_name               3
# style_description        3
# servingTemperature    1652
# foodPairings          1676
# beer_description       356
# labels                 940
# glasswareId           1178
# glass_name            1178
# srmId                 1418
# srm_hex               1418
# srmMin                  73
# srmMax                  77
# dtype: int64

# %%
beer_list2 = pd.read_csv('beers_redux.csv')

# %%
beer_list2.columns = ['unknown',
                     'id',
                     'name',
                     'abv',
                     'ibu',
                     'originalGravity',
                     'ogMin',
                     'isOrganic',
                     'categoryId',
                     'category_name',
                     'styleId',
                     'style_name',
                     'style_description',
                     'servingTemperature',
                     'foodPairings',
                     'beer_description',
                     'labels',
                     'glasswareId',
                     'glass_name',
                     'srmId',
                     'srm_hex',
                     'srmMin',
                     'srmMax'
                     ]

# %%
beers = pd.concat([beer_list2,beer_list], axis = 0)

# %%
beers= pd.read_csv('beers.csv')

# %%
beers.isnull().sum()
# Out:
# Unnamed: 0                0
# unknown                   0
# id                        0
# name                      0
# abv                     193
# ibu                       0
# originalGravity       15719
# ogMin                  1407
# isOrganic                 0
# categoryId               76
# category_name            76
# styleId                  76
# style_name               76
# style_description        80
# servingTemperature    17318
# foodPairings          17559
# beer_description       3578
# labels                11184
# glasswareId           12232
# glass_name            12232
# srmId                 15069
# srm_hex               15069
# srmMin                 1385
# srmMax                 1416
# dtype: int64

# %%
beer = beers.drop(['Unnamed: 0','unknown','servingTemperature','foodPairings','labels','glasswareId','glass_name'], axis=1)

# %%
beer.tail()
# Out:
#            id                               name   abv  ibu  originalGravity  \
# 19548  aG4Ie2             Alpha Dog Imperial IPA   8.0  127              NaN
# 19549  6LIgX5           G/I/A/A V2.0 (Ghost 195)  11.0  127              NaN
# 19550  dCkDCc  G/I/A/A V2.0 - Mezcal (Ghost 339)  11.0  127              NaN
# 19551  AUwmFb             Heavyweight Double IPA  10.7  127              NaN
# 19552  G98I8B                          S.N.A.F.U  11.1  127              NaN
#
#        ogMin isOrganic  categoryId               category_name  styleId  \
# 19548  1.075         N         3.0  North American Origin Ales     31.0
# 19549  1.075         N         3.0  North American Origin Ales     31.0
# 19550  1.075         N         3.0  North American Origin Ales     31.0
# 19551  1.075         N         3.0  North American Origin Ales     31.0
# 19552  1.075         N         3.0  North American Origin Ales     31.0
#
#                               style_name  \
# 19548  Imperial or Double India Pale Ale
# 19549  Imperial or Double India Pale Ale
# 19550  Imperial or Double India Pale Ale
# 19551  Imperial or Double India Pale Ale
# 19552  Imperial or Double India Pale Ale
#
#                                        style_description  \
# 19548  Imperial or Double India Pale Ales have intens...
# 19549  Imperial or Double India Pale Ales have intens...
# 19550  Imperial or Double India Pale Ales have intens...
# 19551  Imperial or Double India Pale Ales have intens...
# 19552  Imperial or Double India Pale Ales have intens...
#
#                                         beer_description  srmId srm_hex  \
# 19548  A True Hop Bomb Brewed plenty of Columbus and ...    6.0  F8A600
# 19549  The world trembles with the beat: the marching...    NaN     NaN
# 19550  The world trembles with the beat: the marching...   15.0  BB5100
# 19551                                                NaN    NaN     NaN
# 19552  S.N.A.F.U is a double IPA, AKA DIPA, heavy hop...    NaN     NaN
#
#        srmMin  srmMax
# 19548     5.0    13.0
# 19549     5.0    13.0
# 19550     5.0    13.0
# 19551     5.0    13.0
# 19552     5.0    13.0

# %%
type(beer['beer_description'][0])
# Out:
# float

# %%
for index, row in beer.iterrows():
#     print row['srmId']>0
    if not row['srmId'] > 0:
#         print  (row['srmMin']+row['srmMax'])/2
        beer.loc[index, 'srmId'] = (row['srmMin']+row['srmMax'])/2
    if not row['originalGravity'] > 0:
        beer.loc[index, 'originalGravity'] = row['ogMin']
    
beer.isnull().sum()
# Out:
# id                       0
# name                     0
# abv                    193
# ibu                      0
# originalGravity       1126
# ogMin                 1407
# isOrganic                0
# categoryId              76
# category_name           76
# styleId                 76
# style_name              76
# style_description       80
# beer_description      3578
# srmId                 1066
# srm_hex              15069
# srmMin                1385
# srmMax                1416
# dtype: int64

# %%
beer.drop(['srm_hex'],axis = 1)
# Out:
#            id                               name   abv  ibu  originalGravity  \
# 0      njehqH                            144 IPA   NaN    0            1.060
# 1      EVVV1r                   1488 Whisky Beer   7.0    0              NaN
# 2      295GZo               19 Original Colonies   5.5    0            1.008
# 3      Np1soi           666 Premium British Beer   6.6    0            1.033
# 4      7xU7NH                      Ace of Simcoe   4.5    0              NaN
# 5      KgqNri               After Party Pale Ale   5.3    0            1.060
# 6      TwnIXA                          Amber Rye   5.5    0            1.044
# 7      O6CToa               American Barley Wine  11.5    0            1.090
# 8      3D7Ba5                       American IPA   5.0    0            1.060
# 9      MDmjnK                 Artesian Light Ale   3.8    0            1.045
# 10     imBibw      Atlantic Exceptional Pale Ale   4.2    0            1.060
# 11     Voyn1N                     Atlantic White   6.0    0            1.060
# 12     CtmZFl               Beer Geek Flat Black   7.5    0            1.038
# 13     Q3NVzi                        Benevolence   NaN    0              NaN
# 14     Ejpwsh                    Bergen Pale Ale   4.7    0            1.044
# 15     BawPdw               Bernard Světlý Ležák   4.7    0            1.044
# 16     4PXivT                             Bitter   4.2    0            1.045
# 17     7xiMuK                 Black Cherry Stout   NaN    0            1.050
# 18     TbZRfB                          Black IPA   6.5    0            1.056
# 19     Mb9zDC            Black Wolf Smoked Stout   NaN    0              NaN
# 20     k4ncgi                         Blood Moon   9.4    0            1.080
# 21     nEPCDE                     Bobs Yer Uncle   NaN    0            1.046
# 22     IxW0mi                         Boot Tread   NaN    0            1.054
# 23     fQed08                             Boysen  10.0    0            1.064
# 24     3uIDIQ                    Brassin d'Hiver   7.2    0            1.030
# 25     AugO3n                             Bretta   NaN    0              NaN
# 26     RBH0iH                 Brewers Cut No. 25   NaN    0            1.045
# 27     Dir8rt                          Bu Weisse   2.1    0            1.028
# 28     X0vXc3                   Bulmers Original   4.5    0            1.045
# 29     EMtuqJ                  Bumblestick Brown   NaN    0            1.040
# ...       ...                                ...   ...  ...              ...
# 19523  MsORGu                         Zacks IIPA   9.0  121            1.075
# 19524  pxZ7dn          ‘BARLEY LEGAL’ BARLEYWINE  14.2  121            1.090
# 19525  j6RzyV                 Af Brew Old Sparky  10.0  122            1.030
# 19526  8OkEC3                  Edge City 1.5 IPA  10.7  122            1.075
# 19527  1rBLbZ                          Hoparillo  11.1  122            1.075
# 19528  DrRRMp                     Hoppy Accident   NaN  122            1.075
# 19529  LMduNl                       Imperial IPA   8.6  122            1.075
# 19530  DKV2Fz              Is this the Real Life   7.2  122            1.060
# 19531  15CSM8         Mongoose Slayer Double IPA   9.9  122            1.075
# 19532  qBAFWG                 Squatch Double IPA   7.5  122            1.080
# 19533  mMInIF                        Gallinipper  12.5  123            1.096
# 19534  7Bm327         Mo' Shuggie Soulbender IPA   7.4  123            1.075
# 19535  jBkvwv                            Bolshoi  12.4  124            1.080
# 19536  P4ovR4                Double Dragon Point   8.2  124            1.075
# 19537  q2pUEz                            Hoptasm   8.7  125            1.075
# 19538  YupDGf                       Hypothetical  13.3  125            1.113
# 19539  iB0NTA                           Mint IPA   7.7  125            1.060
# 19540  DLFduy                          Rye Cubed  10.7  125            1.095
# 19541  QCSsvy            The Pit Boss Triple IPA  12.0  125            1.060
# 19542  LAwdpW              Uppercut Imperial IPA   9.3  125            1.075
# 19543  aDAIRA       Against the Grain Hybrid IPA   7.2  126              NaN
# 19544  Ui1a7c                           AlphaDog   8.5  126            1.075
# 19545  Qr4aPY                          Big A IPA   9.7  126            1.087
# 19546  yXZP0b                      Cysquatch IPA   7.1  126            1.060
# 19547  IB8TX1                  Seeing Double IPA   9.5  126            1.075
# 19548  aG4Ie2             Alpha Dog Imperial IPA   8.0  127            1.075
# 19549  6LIgX5           G/I/A/A V2.0 (Ghost 195)  11.0  127            1.075
# 19550  dCkDCc  G/I/A/A V2.0 - Mezcal (Ghost 339)  11.0  127            1.075
# 19551  AUwmFb             Heavyweight Double IPA  10.7  127            1.075
# 19552  G98I8B                          S.N.A.F.U  11.1  127            1.075
#
#        ogMin isOrganic  categoryId                   category_name  styleId  \
# 0      1.060         N         3.0      North American Origin Ales     30.0
# 1        NaN         N        11.0               Hybrid/mixed Beer    138.0
# 2        NaN         Y        12.0            Mead, Cider, & Perry    148.0
# 3      1.033         N         1.0             British Origin Ales      3.0
# 4        NaN         N         3.0      North American Origin Ales    164.0
# 5      1.060         N         3.0      North American Origin Ales     30.0
# 6      1.044         N         8.0            North American Lager     97.0
# 7      1.090         N         3.0      North American Origin Ales     34.0
# 8      1.060         N         3.0      North American Origin Ales     30.0
# 9      1.045         N         3.0      North American Origin Ales     36.0
# 10     1.060         N         3.0      North American Origin Ales     30.0
# 11     1.060         N         3.0      North American Origin Ales     30.0
# 12     1.038         N         1.0             British Origin Ales     21.0
# 13       NaN         N         3.0      North American Origin Ales     40.0
# 14     1.044         N         3.0      North American Origin Ales     25.0
# 15     1.044         N         7.0         European-germanic Lager     76.0
# 16     1.045         N         3.0      North American Origin Ales     36.0
# 17     1.050         N         3.0      North American Origin Ales     42.0
# 18     1.056         N         3.0      North American Origin Ales     41.0
# 19       NaN         N        11.0               Hybrid/mixed Beer    129.0
# 20     1.080         N         3.0      North American Origin Ales     33.0
# 21     1.046         N         1.0             British Origin Ales      5.0
# 22     1.054         N         5.0  Belgian And French Origin Ales     61.0
# 23     1.064         N         5.0  Belgian And French Origin Ales     64.0
# 24     1.030         N        11.0               Hybrid/mixed Beer    124.0
# 25       NaN         N        11.0               Hybrid/mixed Beer     39.0
# 26     1.045         N         8.0            North American Lager     98.0
# 27     1.028         N         4.0              German Origin Ales     46.0
# 28     1.045         N        12.0            Mead, Cider, & Perry    149.0
# 29     1.040         N         3.0      North American Origin Ales     37.0
# ...      ...       ...         ...                             ...      ...
# 19523  1.075         N         3.0      North American Origin Ales     31.0
# 19524  1.090         N         3.0      North American Origin Ales     34.0
# 19525  1.030         N         1.0             British Origin Ales     10.0
# 19526  1.075         N         3.0      North American Origin Ales     31.0
# 19527  1.075         N         3.0      North American Origin Ales     31.0
# 19528  1.075         N         3.0      North American Origin Ales     31.0
# 19529  1.075         N         3.0      North American Origin Ales     31.0
# 19530  1.060         N         3.0      North American Origin Ales     30.0
# 19531  1.075         N         3.0      North American Origin Ales     31.0
# 19532  1.080         N         3.0      North American Origin Ales     33.0
# 19533  1.090         N         3.0      North American Origin Ales     34.0
# 19534  1.075         N         3.0      North American Origin Ales     31.0
# 19535  1.080         N         3.0      North American Origin Ales     43.0
# 19536  1.075         N         3.0      North American Origin Ales     31.0
# 19537  1.075         N         3.0      North American Origin Ales     31.0
# 19538    NaN         N         NaN                             NaN      NaN
# 19539  1.060         N         3.0      North American Origin Ales     30.0
# 19540  1.075         N         3.0      North American Origin Ales     31.0
# 19541  1.060         Y         3.0      North American Origin Ales     30.0
# 19542  1.075         N         3.0      North American Origin Ales     31.0
# 19543    NaN         N         5.0  Belgian And French Origin Ales     70.0
# 19544  1.075         N         3.0      North American Origin Ales     31.0
# 19545  1.075         N         3.0      North American Origin Ales     31.0
# 19546  1.060         N         3.0      North American Origin Ales     30.0
# 19547  1.075         N         3.0      North American Origin Ales     31.0
# 19548  1.075         N         3.0      North American Origin Ales     31.0
# 19549  1.075         N         3.0      North American Origin Ales     31.0
# 19550  1.075         N         3.0      North American Origin Ales     31.0
# 19551  1.075         N         3.0      North American Origin Ales     31.0
# 19552  1.075         N         3.0      North American Origin Ales     31.0
#
#                               style_name  \
# 0          American-Style India Pale Ale
# 1              Other Strong Ale or Lager
# 2                     Open Category Mead
# 3                        Ordinary Bitter
# 4                 Session India Pale Ale
# 5          American-Style India Pale Ale
# 6           American-Style Premium Lager
# 7         American-Style Barley Wine Ale
# 8          American-Style India Pale Ale
# 9                   Golden or Blonde Ale
# 10         American-Style India Pale Ale
# 11         American-Style India Pale Ale
# 12                         Oatmeal Stout
# 13               American-Style Sour Ale
# 14               American-Style Pale Ale
# 15               Bohemian-Style Pilsener
# 16                  Golden or Blonde Ale
# 17                  American-Style Stout
# 18              American-Style Black Ale
# 19             Smoke Beer (Lager or Ale)
# 20                      Imperial Red Ale
# 21                  Extra Special Bitter
# 22              Belgian-Style Blonde Ale
# 23         Belgian-Style Dark Strong Ale
# 24                   Herb and Spice Beer
# 25                            Brett Beer
# 26               American-Style Pilsener
# 27         Berliner-Style Weisse (Wheat)
# 28                          Common Cider
# 29              American-Style Brown Ale
# ...                                  ...
# 19523  Imperial or Double India Pale Ale
# 19524     American-Style Barley Wine Ale
# 19525        English-Style Pale Mild Ale
# 19526  Imperial or Double India Pale Ale
# 19527  Imperial or Double India Pale Ale
# 19528  Imperial or Double India Pale Ale
# 19529  Imperial or Double India Pale Ale
# 19530      American-Style India Pale Ale
# 19531  Imperial or Double India Pale Ale
# 19532                   Imperial Red Ale
# 19533     American-Style Barley Wine Ale
# 19534  Imperial or Double India Pale Ale
# 19535      American-Style Imperial Stout
# 19536  Imperial or Double India Pale Ale
# 19537  Imperial or Double India Pale Ale
# 19538                                NaN
# 19539      American-Style India Pale Ale
# 19540  Imperial or Double India Pale Ale
# 19541      American-Style India Pale Ale
# 19542  Imperial or Double India Pale Ale
# 19543           Other Belgian-Style Ales
# 19544  Imperial or Double India Pale Ale
# 19545  Imperial or Double India Pale Ale
# 19546      American-Style India Pale Ale
# 19547  Imperial or Double India Pale Ale
# 19548  Imperial or Double India Pale Ale
# 19549  Imperial or Double India Pale Ale
# 19550  Imperial or Double India Pale Ale
# 19551  Imperial or Double India Pale Ale
# 19552  Imperial or Double India Pale Ale
#
#                                        style_description  \
# 0      American-style India pale ales are perceived t...
# 1      Any style of beer can be made stronger than th...
# 2      This mead should exhibit the character of all ...
# 3      Ordinary bitter is gold to copper colored with...
# 4      Session India Pale Ales are gold to copper. Ch...
# 5      American-style India pale ales are perceived t...
# 6      This style has low malt (and adjunct) sweetnes...
# 7      American style barley wines range from amber t...
# 8      American-style India pale ales are perceived t...
# 9      Golden or Blonde ales are straw to golden blon...
# 10     American-style India pale ales are perceived t...
# 11     American-style India pale ales are perceived t...
# 12     Oatmeal stouts include oatmeal in their grist,...
# 13     American sour ales can be very light to black ...
# 14     American pale ales range from deep golden to c...
# 15     Traditional Bohemian Pilseners are medium bodi...
# 16     Golden or Blonde ales are straw to golden blon...
# 17     Initial low to medium malt sweetness with a de...
# 18     American-style Black Ales are very dark to bla...
# 19     Any style of beer can be smoked; the goal is t...
# 20     Imperial Red Ales are deep amber to dark coppe...
# 21     Extra special bitter possesses medium to stron...
# 22     Belgian-style blond ales are characterized by ...
# 23     Belgian dark strong ales are amber to dark bro...
# 24     Herb beers use herbs or spices (derived from r...
# 25     Brett Beers are any range of color and may tak...
# 26     This classic and unique pre-Prohibition Americ...
# 27     This is very pale in color and the lightest of...
# 28     Variable, but should be a medium, refreshing d...
# 29     American brown ales range from deep copper to ...
# ...                                                  ...
# 19523  Imperial or Double India Pale Ales have intens...
# 19524  American style barley wines range from amber t...
# 19525  English pale mild ales range from golden to am...
# 19526  Imperial or Double India Pale Ales have intens...
# 19527  Imperial or Double India Pale Ales have intens...
# 19528  Imperial or Double India Pale Ales have intens...
# 19529  Imperial or Double India Pale Ales have intens...
# 19530  American-style India pale ales are perceived t...
# 19531  Imperial or Double India Pale Ales have intens...
# 19532  Imperial Red Ales are deep amber to dark coppe...
# 19533  American style barley wines range from amber t...
# 19534  Imperial or Double India Pale Ales have intens...
# 19535  Black in color, American-style imperial stouts...
# 19536  Imperial or Double India Pale Ales have intens...
# 19537  Imperial or Double India Pale Ales have intens...
# 19538                                                NaN
# 19539  American-style India pale ales are perceived t...
# 19540  Imperial or Double India Pale Ales have intens...
# 19541  American-style India pale ales are perceived t...
# 19542  Imperial or Double India Pale Ales have intens...
# 19543  Recognizing the uniqueness and traditions of s...
# 19544  Imperial or Double India Pale Ales have intens...
# 19545  Imperial or Double India Pale Ales have intens...
# 19546  American-style India pale ales are perceived t...
# 19547  Imperial or Double India Pale Ales have intens...
# 19548  Imperial or Double India Pale Ales have intens...
# 19549  Imperial or Double India Pale Ales have intens...
# 19550  Imperial or Double India Pale Ales have intens...
# 19551  Imperial or Double India Pale Ales have intens...
# 19552  Imperial or Double India Pale Ales have intens...
#
#                                         beer_description  srmId  srmMin  \
# 0                                                    NaN   10.0     6.0
# 1                                                    NaN    NaN     NaN
# 2      19 Original Colonies Mead is brewed using 5 in...    NaN     NaN
# 3                                                    NaN    8.5     5.0
# 4                                                    NaN    NaN     NaN
# 5                                                    NaN   10.0     6.0
# 6                                                    NaN    4.0     2.0
# 7                                                    NaN   16.5    11.0
# 8                                                    NaN   10.0     6.0
# 9                                                    NaN    5.0     3.0
# 10                                                   NaN   10.0     6.0
# 11                                                   NaN   10.0     6.0
# 12                                                   NaN   20.0    20.0
# 13                                                   NaN    NaN     NaN
# 14                                                   NaN   10.0     6.0
# 15                                                   NaN    5.0     3.0
# 16                                                   NaN    5.0     3.0
# 17                                                   NaN   40.0    40.0
# 18                                                   NaN   35.0    35.0
# 19                                                   NaN    NaN     NaN
# 20                                                   NaN   12.5    10.0
# 21                                                   NaN   11.0     8.0
# 22                                                   NaN    5.5     4.0
# 23                                                   NaN   22.0     9.0
# 24                                                   NaN   27.5     5.0
# 25                                                   NaN    NaN     NaN
# 26                                                   NaN    4.5     3.0
# 27                                                   NaN    3.0     2.0
# 28                                                   NaN    NaN     NaN
# 29                                                   NaN   20.5    15.0
# ...                                                  ...    ...     ...
# 19523  December  2011 - Zacks IIPA - designed by Home...    9.0     5.0
# 19524  Massive amounts of hops (3x the amount that go...   16.5    11.0
# 19525                                                NaN   12.5     8.0
# 19526  Since our Double IPA is so huge, we decided to...    9.0     5.0
# 19527                                                NaN    9.0     5.0
# 19528  Don't let the word 'accident' scare you.\r\r\r...    9.0     5.0
# 19529                                                NaN    9.0     5.0
# 19530                                                NaN   10.0     6.0
# 19531  Intensely Hoppy, Pine, Citrus, Tropical Fruits...    9.0     5.0
# 19532  This is a big beer!...with 122 IBU's and weigh...   12.5    10.0
# 19533                                                NaN   16.5    11.0
# 19534                                                NaN    9.0     5.0
# 19535  Massive, pitch-black and complex brew made wit...   38.0    40.0
# 19536  This double IPA was brewed like Dragon Point, ...    9.0     5.0
# 19537  This is our tribute to the crazy world of big ...    9.0     5.0
# 19538  This hop megatron bomb blasts your palette in ...    NaN     NaN
# 19539  This IPA has 11 hop additions using 5 differen...   10.0     6.0
# 19540  Rye beers have been a part of our brewing arse...    9.0     5.0
# 19541  An Imperial IPA brewed with copious amounts of...   10.0     6.0
# 19542  This beer is an expression of our love for hop...    9.0     5.0
# 19543  Our hybrid IPA takes the classic West coast st...    NaN     NaN
# 19544  A True Hop Bomb Brewed plenty of Columbus and ...    9.0     5.0
# 19545  Ever since Stash Wojciechowski, the “Killer Ki...   13.0     5.0
# 19546  A mix of West Coast IPA and English yeast alon...   10.0     6.0
# 19547  Foothills' first high gravity beer. The high l...    9.0     5.0
# 19548  A True Hop Bomb Brewed plenty of Columbus and ...    6.0     5.0
# 19549  The world trembles with the beat: the marching...    9.0     5.0
# 19550  The world trembles with the beat: the marching...   15.0     5.0
# 19551                                                NaN    9.0     5.0
# 19552  S.N.A.F.U is a double IPA, AKA DIPA, heavy hop...    9.0     5.0
#
#        srmMax
# 0        14.0
# 1         NaN
# 2         NaN
# 3        12.0
# 4         NaN
# 5        14.0
# 6         6.0
# 7        22.0
# 8        14.0
# 9         7.0
# 10       14.0
# 11       14.0
# 12       20.0
# 13        NaN
# 14       14.0
# 15        7.0
# 16        7.0
# 17       40.0
# 18       35.0
# 19        NaN
# 20       15.0
# 21       14.0
# 22        7.0
# 23       35.0
# 24       50.0
# 25        NaN
# 26        6.0
# 27        4.0
# 28        NaN
# 29       26.0
# ...       ...
# 19523    13.0
# 19524    22.0
# 19525    17.0
# 19526    13.0
# 19527    13.0
# 19528    13.0
# 19529    13.0
# 19530    14.0
# 19531    13.0
# 19532    15.0
# 19533    22.0
# 19534    13.0
# 19535    40.0
# 19536    13.0
# 19537    13.0
# 19538     NaN
# 19539    14.0
# 19540    13.0
# 19541    14.0
# 19542    13.0
# 19543     NaN
# 19544    13.0
# 19545    13.0
# 19546    14.0
# 19547    13.0
# 19548    13.0
# 19549    13.0
# 19550    13.0
# 19551    13.0
# 19552    13.0
#
# [19553 rows x 16 columns]

# %%
brew_num = str(4)
r = requests.get('https://www.beeradvocate.com/beer/profile/'+brew_num)
b = BeautifulSoup(r.text, 'html.parser')
b.prettify()

# %%
reg_tag = re.compile("/beer/profile/\d+/\d+/")
reg2_tag = re.compile('\d.\d+')
reg3_tag = re.compile('\a+')
a_tag = b.findAll('a' , attrs={'href': reg_tag})
b_links={'Name':[], 'url':[] }
for a in a_tag:
    b_links['Name'].append(a.text)
for link in a_tag:
    b_links['url'].append(link.get('href'))

# %%
beer_list[beer_list['beer_description'].isnull()].head()
# Out:
#    unknown      id                      name  abv  ibu  originalGravity  \
# 0        0  njehqH                   144 IPA  NaN    0              NaN
# 1        1  EVVV1r          1488 Whisky Beer  7.0    0              NaN
# 3        3  Np1soi  666 Premium British Beer  6.6    0              NaN
# 4        4  7xU7NH             Ace of Simcoe  4.5    0              NaN
# 5        5  KgqNri      After Party Pale Ale  5.3    0              NaN
#
#    ogMin isOrganic  categoryId               category_name   ...    \
# 0  1.060         N         3.0  North American Origin Ales   ...
# 1    NaN         N        11.0           Hybrid/mixed Beer   ...
# 3  1.033         N         1.0         British Origin Ales   ...
# 4    NaN         N         3.0  North American Origin Ales   ...
# 5  1.060         N         3.0  North American Origin Ales   ...
#
#    servingTemperature foodPairings beer_description labels glasswareId  \
# 0                 NaN          NaN              NaN    NaN         NaN
# 1                 NaN          NaN              NaN    NaN         NaN
# 3                 NaN          NaN              NaN    NaN         NaN
# 4                 NaN          NaN              NaN    NaN         NaN
# 5                 NaN          NaN              NaN    NaN         NaN
#
#   glass_name srmId  srm_hex srmMin  srmMax
# 0        NaN   NaN      NaN    6.0    14.0
# 1        NaN   NaN      NaN    NaN     NaN
# 3        NaN   NaN      NaN    5.0    12.0
# 4        NaN   NaN      NaN    NaN     NaN
# 5        NaN   NaN      NaN    6.0    14.0
#
# [5 rows x 23 columns]

# %%
#r = requests.get('https://www.beeradvocate.com/search/?q=allagash+confluence&qt=beer')
#b = BeautifulSoup(r.text, 'html.parser')
#b.findAll('b')
# Out:
# [<b>Subscribe now!</b>,
#  <b>Found: 2</b>,
#  <b>Allagash Confluence Ale</b>,
#  <b>Allagash Confluence - Raspberry</b>]

# %%
r= requests.get('https://www.beeradvocate.com/beer/profile/4/47277')
b = BeautifulSoup(r.text, 'html.parser')
brs = b.findAll('br')

# %%
def get_desc_from_advocate(url):
    r= requests.get('https://www.beeradvocate.com'+url)
    b = BeautifulSoup(r.text, 'html.parser')
    brs = b.findAll('br')
    for index, be in enumerate(brs):
        if 'notes' in be.text.lower():
            return brs[index+1].text.split('Notes / Commercial Description:')[1].strip()

# %%
reg_tag = re.compile("/beer/profile/\d+/\d+/")
a_tag = b.findAll('a' , attrs={'href': reg_tag})
def get_url_from_beer_name(name):
    urls = []
    r= requests.get('https://www.beeradvocate.com/search/?q='+name.lower()+'&qt=beer')
    b = BeautifulSoup(r.text, 'html.parser')
    a_tag = b.findAll('a' , attrs={'href': reg_tag})
    for link in a_tag:
        urls.append(link.get('href'))
    if urls:
        return urls[0]
    return None

# %%
get_desc_from_advocate('4/47277')
# Out:
# u'Allagash Confluence Ale is created with a mixed fermentation; utilizing our house primary Belgian style yeast in combination with our proprietary Brettanomyces strain. The two yeast strains work in tandem creating a marriage between spice and fruit flavors that ultimately leave a lingering silky mouth feel. Confluence is brewed with a blend of both imported pilsner and domestic pale malts as well as a portion of caramel malt, resulting in a complex malty profile. Tettnang and East Kent Golding hops are added in the brew process to balance the intricate malty profile while adding a sweet and spicy citrus aroma. After fermentation, Confluence undergoes a lengthy aging process in stainless steel tanks to enhance the flavors. Prior to bottling, it is dry hopped with a Glacier hops, providing a pleasant balance of aromas.Added by ClockworkOrange on 01-14-2009'

# %%
get_url_from_beer_name('stella artois')
# Out:
# u'/beer/profile/169/449/'

# %%
def get_desc_from_beer_name(name):
    url = get_url_from_beer_name(name)
    if url:
        return get_desc_from_advocate(url)
    else:
        return None

# %%
get_desc_from_beer_name("ace of simcoe")
# Out:
# u'Single hop awesomeness, shining a spotlight on our favourite ingredient, the not so humble hop. Ace of Simcoe has the ultimate poker face - this session IPA is low in strength but has an ace in the hole - devastating hoppy aroma & flavour. This session IPA has been bombarded with Simcoe. Mango, pine, and grapefruit explode from the glass, firing off from a light, complex toasty malt base. Low voltage, high amplitude hops, in their purest form.Added by flyingpig on 02-29-2016'

# %%
done = 0
for index, row in beer.iterrows():
    if not row['beer_description'] > 0 and row['name']:
        beer.loc[index, 'beer_description'] = get_desc_from_beer_name(row['name'])
        done += 1
        if done % 20 == 0:
            print done
beer.isnull().sum()
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# id                       0
# name                     0
# abv                    193
# ibu                      0
# originalGravity       1126
# ogMin                 1407
# isOrganic                0
# categoryId              76
# category_name           76
# styleId                 76
# style_name              76
# style_description       80
# beer_description       931
# srmId                 1066
# srm_hex              15069
# srmMin                1385
# srmMax                1416
# dtype: int64

# %%
beer.isnull().sum()
# Out:
# id                       0
# name                     0
# abv                    193
# ibu                      0
# originalGravity       1126
# ogMin                 1407
# isOrganic                0
# categoryId              76
# category_name           76
# styleId                 76
# style_name              76
# style_description       80
# beer_description       931
# srmId                 1066
# srm_hex              15069
# srmMin                1385
# srmMax                1416
# dtype: int64

# %%
#del beer['srm_hex']
beer.head(20)
# Out:
#         id                           name   abv  ibu  originalGravity  ogMin  \
# 0   njehqH                        144 IPA   NaN    0            1.060  1.060
# 1   EVVV1r               1488 Whisky Beer   7.0    0              NaN    NaN
# 2   295GZo           19 Original Colonies   5.5    0            1.008    NaN
# 3   Np1soi       666 Premium British Beer   6.6    0            1.033  1.033
# 4   7xU7NH                  Ace of Simcoe   4.5    0              NaN    NaN
# 5   KgqNri           After Party Pale Ale   5.3    0            1.060  1.060
# 6   TwnIXA                      Amber Rye   5.5    0            1.044  1.044
# 7   O6CToa           American Barley Wine  11.5    0            1.090  1.090
# 8   3D7Ba5                   American IPA   5.0    0            1.060  1.060
# 9   MDmjnK             Artesian Light Ale   3.8    0            1.045  1.045
# 10  imBibw  Atlantic Exceptional Pale Ale   4.2    0            1.060  1.060
# 11  Voyn1N                 Atlantic White   6.0    0            1.060  1.060
# 12  CtmZFl           Beer Geek Flat Black   7.5    0            1.038  1.038
# 13  Q3NVzi                    Benevolence   NaN    0              NaN    NaN
# 14  Ejpwsh                Bergen Pale Ale   4.7    0            1.044  1.044
# 15  BawPdw           Bernard Světlý Ležák   4.7    0            1.044  1.044
# 16  4PXivT                         Bitter   4.2    0            1.045  1.045
# 17  7xiMuK             Black Cherry Stout   NaN    0            1.050  1.050
# 18  TbZRfB                      Black IPA   6.5    0            1.056  1.056
# 19  Mb9zDC        Black Wolf Smoked Stout   NaN    0              NaN    NaN
#
#    isOrganic  categoryId               category_name  styleId  \
# 0          N         3.0  North American Origin Ales     30.0
# 1          N        11.0           Hybrid/mixed Beer    138.0
# 2          Y        12.0        Mead, Cider, & Perry    148.0
# 3          N         1.0         British Origin Ales      3.0
# 4          N         3.0  North American Origin Ales    164.0
# 5          N         3.0  North American Origin Ales     30.0
# 6          N         8.0        North American Lager     97.0
# 7          N         3.0  North American Origin Ales     34.0
# 8          N         3.0  North American Origin Ales     30.0
# 9          N         3.0  North American Origin Ales     36.0
# 10         N         3.0  North American Origin Ales     30.0
# 11         N         3.0  North American Origin Ales     30.0
# 12         N         1.0         British Origin Ales     21.0
# 13         N         3.0  North American Origin Ales     40.0
# 14         N         3.0  North American Origin Ales     25.0
# 15         N         7.0     European-germanic Lager     76.0
# 16         N         3.0  North American Origin Ales     36.0
# 17         N         3.0  North American Origin Ales     42.0
# 18         N         3.0  North American Origin Ales     41.0
# 19         N        11.0           Hybrid/mixed Beer    129.0
#
#                         style_name  \
# 0    American-Style India Pale Ale
# 1        Other Strong Ale or Lager
# 2               Open Category Mead
# 3                  Ordinary Bitter
# 4           Session India Pale Ale
# 5    American-Style India Pale Ale
# 6     American-Style Premium Lager
# 7   American-Style Barley Wine Ale
# 8    American-Style India Pale Ale
# 9             Golden or Blonde Ale
# 10   American-Style India Pale Ale
# 11   American-Style India Pale Ale
# 12                   Oatmeal Stout
# 13         American-Style Sour Ale
# 14         American-Style Pale Ale
# 15         Bohemian-Style Pilsener
# 16            Golden or Blonde Ale
# 17            American-Style Stout
# 18        American-Style Black Ale
# 19       Smoke Beer (Lager or Ale)
#
#                                     style_description  \
# 0   American-style India pale ales are perceived t...
# 1   Any style of beer can be made stronger than th...
# 2   This mead should exhibit the character of all ...
# 3   Ordinary bitter is gold to copper colored with...
# 4   Session India Pale Ales are gold to copper. Ch...
# 5   American-style India pale ales are perceived t...
# 6   This style has low malt (and adjunct) sweetnes...
# 7   American style barley wines range from amber t...
# 8   American-style India pale ales are perceived t...
# 9   Golden or Blonde ales are straw to golden blon...
# 10  American-style India pale ales are perceived t...
# 11  American-style India pale ales are perceived t...
# 12  Oatmeal stouts include oatmeal in their grist,...
# 13  American sour ales can be very light to black ...
# 14  American pale ales range from deep golden to c...
# 15  Traditional Bohemian Pilseners are medium bodi...
# 16  Golden or Blonde ales are straw to golden blon...
# 17  Initial low to medium malt sweetness with a de...
# 18  American-style Black Ales are very dark to bla...
# 19  Any style of beer can be smoked; the goal is t...
#
#                                      beer_description  srmId  srmMin  srmMax
# 0   Duplicate listingAdded by ThatsThatDude on 05-...   10.0     6.0    14.0
# 1   No notes at this time.Added by geexploitation ...    NaN     NaN     NaN
# 2   19 Original Colonies Mead is brewed using 5 in...    NaN     NaN     NaN
# 3                                                None    8.5     5.0    12.0
# 4   Single hop awesomeness, shining a spotlight on...    NaN     NaN     NaN
# 5   Duplicate of https://www.beeradvocate.com/beer...   10.0     6.0    14.0
# 6       No notes at this time.Added by  on 09-16-2009    4.0     2.0     6.0
# 7   No notes at this time.Added by mattvandyk on 0...   16.5    11.0    22.0
# 8   Our American IPA gets its bold hop flavor from...   10.0     6.0    14.0
# 9   No notes at this time.Added by EmperorBevis on...    5.0     3.0     7.0
# 10                                               None   10.0     6.0    14.0
# 11  No notes at this time.Added by soulgrowl on 04...   10.0     6.0    14.0
# 12                                               None   20.0    20.0    20.0
# 13  An altogether new and unique creation in the w...    NaN     NaN     NaN
# 14  No notes at this time.Added by Florya on 07-19...   10.0     6.0    14.0
# 15  No notes at this time.Added by Globetrotter on...    5.0     3.0     7.0
# 16  **NOTE: This beer is now called "Brutal IPA" *...    5.0     3.0     7.0
# 17  A good solid stout packed with all the flavour...   40.0    40.0    40.0
# 18  Toasted, chocolaty dark malts align with an as...   35.0    35.0    35.0
# 19                                               None    NaN     NaN     NaN

# %%
beer.to_csv('beers2.csv', encoding = 'utf-8')

# %%
beer = pd.read_csv('beers2.csv')

# %%
beer.shape
# Out:
# (19553, 17)

# %%
beer.isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# name                    0
# abv                   193
# ibu                     0
# originalGravity      1126
# ogMin                1407
# isOrganic               0
# categoryId             76
# category_name          76
# styleId                76
# style_name             76
# style_description      80
# beer_description      931
# srmId                1066
# srmMin               1385
# srmMax               1416
# dtype: int64

# %%
beer['beer_description'].value_counts()
# Out:
# No notes at this time.Added by Quaffer on 09-04-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                24
# Esquire Magazine calls our 90 Minute IPA "perhaps the best IPA in America." An imperial IPA best savored from a snifter, 90 Minute has a great malt backbone that stands up to the extreme hopping rate.\r\n\r\r\n90 Minute IPA was the first beer we continuously hopped, allowing for a pungent -- but not crushing -- hop flavor.\r\n\r\r\n90 IBUAdded by BeerAdvocate on 11-19-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             13
# Toasted, chocolaty dark malts align with an astronomical amount of hops.\r\n\r\r\n109 IBUAdded by TheFlern on 03-10-2011                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             9
# No notes at this time.Added by BeerAdvocate on 12-21-2000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            9
# No notes at this time.Added by kbub6f on 10-07-2000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  8
# Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          7
# No notes at this time.Added by kbub6f on 01-18-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  7
# No notes at this time.Added by ClockworkOrange on 03-12-2009                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         7
# No notes at this time.Added by Todd on 11-15-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    6
# Generous quantities of premium Cascade hops give the Pale Ale its fragrant bouquet and spicy flavor.\r\n\r\r\n37 IBUAdded by kbub6f on 07-05-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    6
# Our award-winning barleywine boasts a dense, fruity bouquet, an intense flavor palate and a deep reddish-brown color. Its big maltiness is superbly balanced by a wonderfully bittersweet hoppiness.\r\r\r\r\n\r\r\r\r\n\r\r\r\r\nMalts: Two Row Pale & English Carmel\r\r\r\r\nYeast: Ale Yeast\r\r\r\r\nBittering Hops: Chinook\r\r\r\r\nFinishing Hops: Cascade & Centennial\r\r\r\r\nDry Hops: Cascade, Centennial & Chinook                                                                                                                                                                                                                                                                                                                                                                                                                                                                     6
# No notes at this time.Added by Bitterbill on 09-10-2000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              6
# HERCULES DOUBLE IPA is not for the faint of heart. It is, however, fit for the gods. HERCULES delivers a huge amount of hops from start to finish. Its hefty backbone of nutty, malty sweetness balances its aggressive hop profile. 85 IBUs.Added by filabrazilia on 04-11-2004                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     6
# Brewed by Harpoon brewer Katie Tame, using Island Creek oyster farmer Skip Bennett’s revered Duxbury Bay oysters, this beer has a rich body and smooth mouthfeel derived in part from a combination of roasted barley and chocolate rye malts. The roasted malt notes blend beautifully with the briny, mineral flavors of the Island Creek oysters. An addition of hops adds some bitterness to balance the malt sweetness. This, the 30th installment of the Harpoon 100 Barrel Series, is best enjoyed with a plate full of Island Creek Oysters.\r\n\r\r\n35 IBUAdded by BeerAdvocate on 01-21-2010This beer is retired; no longer brewed.                                                                                                                                                                                                                                                       6
# No notes at this time.Added by BeerAdvocate on 12-05-2000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6
# No absence of hops gives Founders' robust porter the full flavor you deserve and expect. \r\n\r\r\n45 IBUAdded by BeerAdvocate on 02-11-2003                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# No notes at this time.Added by jaydoc on 01-19-2016                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# Available September to March.Added by ypsifly on 01-28-2006                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          5
# No notes at this time.Added by kbub6f on 07-08-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# No notes at this time.Added by papat444 on 12-10-2015                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                5
# Classified by the brewery as an "Imperial Red/Double IPA" 8.7% ABV, 60 IBUsAdded by BeerAdvocate on 03-12-2003                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       5
# Availability: Sep - Dec\r\n\r\r\nBrewed with flaked oats, bitter and sweetened imported chocolates, Sumatra and Kona coffee.\r\n\r\r\n60 IBUAdded by marburg on 07-26-2003                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           5
# No notes at this time.Added by DrunkinYogi on 01-06-2016                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             5
# No notes at this time.Added by BeerFMAndy on 04-25-2014This beer is retired; no longer brewed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       5
# No notes at this time.Added by tdm168 on 05-07-2015                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# Our Dry Hopped American Pale Ale (APA) is charged with American hops to create a bold, aromatic ale. Assertive hop flavor joins the pine/citrus aroma characteristic of American hops to balance the full body provided by North American malts. After fermentation, the beer circulates through a bed of Cascade and Chinook hops, boosting the distinctive hop aroma of this satisfying ale.\r\n\r\r\nIn the long view of the history of beer, American Pale Ale is a newcomer.  Based on English Pale Ale, American brewers adapted this style into something new.  Born out of the reverence English Pale Ales during the 1980’s American beer scene, APA is the bold, hoppier cousin of Pale Ale.  With an emphasis on American hops, APA is gaining popularity with breweries racing to make these ales with such great hop characters.\r\n\r\r\n50 IBUAdded by BeerAdvocate on 04-09-2007     5
# No notes at this time.Added by Iamjeff6 on 11-06-2015                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                5
# No notes at this time.Added by BeerAdvocate on 09-15-2001                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            5
# No notes at this time.Added by kbub6f on 02-06-1998                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  4
# No notes at this time.Added by SpaCityJonboy on 06-23-2015                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           4
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ..
# Our second offering. Not for the hop squeamish.  Anti-sessionable in nature, Mother Hoppin' is deep orange in color, rich in malty sweetness and heavily dry hopped with Amarillo hops.  10.1%  ABV and 93 IBUs.  Keep an eye out for her every 3 months or so on as a limited small batch release.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Ole Rowdy Rooster is an unfiltered west coast style double IPA​ with light to medium hop haze, caused by the massive amount of dank American hops. The 'Rooster' has a juicy tropical fruit flavor and aroma, this beer pushes the limits of bittering without destroying your pallet. The 8% ABV is smooth and dangerous!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# The Beer from IPAnema    11% ABV,  100 IBU’s\r\r\r\nThis beer is brewed in the Double IPA style. \r\r\r\nIt is very strong in alcohol and should be treated with respect. This brew is rich with soft malt notes and the pineapple like aroma of Mosaic hops.  Alcohol provides the burn and the body to stand up the IBU load in this Hopzilla of a brew. \r\r\r\n \r\r\r\n♫ Tall and tan and young and lovely\r\r\r\nThe beer from Ipanema goes walking\r\r\r\nAnd when she passes, each one she passes goes “A-a-a-h” ♫                                                                                                                                                                                                                                                                                                                                                                           1
# Deacon Blues is a hazy yellow Extra Pale Ale brewed with bold American hops, but fermented with a Belgian yeast strain.  Diverse aromas of pronounced citrus fruit with subtle layers of spiciness, are the first indication of the array of flavors stemming from this light bodied ale.  Snappy lemon qualities, along with a fresh ginger-like liveliness, flow appropriately into a grassy bitterness that’s moderately intense, but certainly not overwhelming.                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Barrio Rojo is our newest version of a low hop, very malty, Scottish Ale. Traditionally Scottish Ales contained very minimal to zero hops allowing the higher amount of malt to shine through in the form of sweetness. We took our time to caramelize the brewing sugars to create a low bitterness, sweet beer with notes of caramel brown sugar and cinnamon.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Milk stout made with oats and locally roasted Coffee Emporium coffee. Moo-cha-licious.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Our first “real” collaboration other brewers was done with Aaron and Ben Lucas, a duo of brew-happy brothers that work at Closed for Business. It’s a triple threat of sorts - a hoppy, rye, brown ale. While it’s a bit strong for the style, the big hop addition and the rye’s bitterness help contribute to the proverbial “bite,” cutting cleanly through the malt for a balanced drinking experience.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Farrell’s Irish Red was the first beer ever produced by Nebraska Brewing Company.  A medium bodied ale  that has found its was into the hearts of our faithful fans and embraced by all who enjoy its subtle mesh of rich malted barley varieties.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# This American sour is a celebration of 21 years of brewing. Soured with lactobacillus and brettanomyces and aged for 9 months in wine barrels.Added by Prospero on 01-24-2015This beer is retired; no longer brewed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# This is a great representation of the style. With a diverse malt bill, Hersbrucker, and Czech Saaz hops you can enjoy all the wonderful flavors a farmhouse ale has to offer balancing hops, malt, and the earthy flavors of saison yeast.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# East coast style IPA with strong earthy resin and citrus notes from Nugget, Centennial and Equinox hops; finishes hoppy and dry.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# The Alpha refers to this beers strength and it's alpha acid content.\r\r\r\r\n\r\r\r\r\nThe next brew in our Mastodon series of IPAs, we went big again. Heavily hopped, \r\r\r\r\n\r\r\r\r\nand then dry-hopped twice to enhance the Cascade hop aroma. If you hate hops, \r\r\r\r\n\r\r\r\r\nthen you will hate this beer!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# This Black IPA is jammed with hop flavor from Simcoe and Ahtanum hops with the addition of rye malt to add a smooth finish.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# We paired up with a local Iowa City roaster to combine two of the greatest black beverages.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Collaboration with Yeastie Boys of New Zealand.Added by ADZA on 09-07-2012This beer is retired; no longer brewed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# This deep, dark, viscous brew stands up to other imperial stouts while standing out from the pack thanks to a harmonious infusion of two different hop varieties – Nugget and Centennial. \r\r\r\r\nRobust and chocolaty, with a spike of hop freshness, it's the perfect beer to warm up with as winter sets in.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# No notes at this time.Added by mountaincoffee on 04-27-2014                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Real spearmint and peppermint\r\r\r\r\n\r\r\r\r\nNot extract — combine with cocoa nibs and vanilla beans to create your reward for making it through winter.\r\r\r\r\n\r\r\r\r\nAncient Greeks tell us (’cause we talk to them) that Persephone turned Minthe into a mint plant in a jealous rage, to keep the little nymph away from her man Hades. Jealous rages rarely end well, but if one did result in mint we’re glad: this is a unique and delicious stout, and we recommend having one while you calm the hell down.\r\r\r\r\n\r\r\r\r\nSOUL MATES  - A sweet stout with real peppermint, spearmint, cocoa nibs and vanilla beans. A great dessert beer, or try it alongside any dish with mint in it, like Thai Grilled Beef Salad.                                                                                                                                                        1
# Ölen du håller i din hand är en American Pale Ale (APA). När denna skapades i USA användes den lokalt odlade humlen. Detta gav rikliga toner av citrus. Som brukligt är i USA snålades det inte heller med dom väldoftande råvarorna.\r\r\r\r\nMycket är helt enkelt mer! \r\r\r\r\n\r\r\r\r\n"Jag brinner för att göra öl med tydlig humlekaraktär. Här har jag arbetat med humlesorterna Cascade och Citra som ger en fräsch citruston."                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# LMFAO Stout aged with vanilla beans.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# An stronger pale ale brewed with english malt for its biscuit and nutty flavor profile and west coast hops bringing out some citrus and floral flavors.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# No notes at this time.Added by sinstaineddemon on 05-26-2009This beer is retired; no longer brewed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Our spiced brown ale brewed with cloves, cinnamon, allspice and ginger just in time for the holidays. This unique brew from the mind of Brewer Jon is a deliciously sweet, spicy, earthy beer here to help you enjoy family and hearth.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Russian Imperial Stout oaked for two weeks on medium+ roast oak spiral, brewed for CBC Copenhagen Beer Celebration 2016 (Scandinavian Bar)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Oktoberfest Märzen – Characterized by a medium body, a malty flavor and a clean dry finish, this is our version of the traditional Oktoberfest beer originating in 16th century Bavaria. 23 IBU’s and 5% ABV                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Brewed originally in 2010 to celebrate our one-hundredth batch at the brewpub and the third installment of our Fist series, this is one seriously hoppy ale! A beautiful burnt orange hue and a underlying caramel flavor to balance out the hop bitterness. Aromas of fresh-cut tangerines and mango from Citra, Cascade, and Chinook hops. The rest is up to your imagination.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Crisp California IPA. Tropical, resinous, and intensely dank!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Mahogany in color, Rook has a bold malt character with woody notes. Peat smoked malt creates a distinctive earthy Scottish flavor that complements English toffee notes. Ideally served at 50 - 55°F.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Copper colored and hazy IPA features seven "C" hops with an extra large dose of Centennial; aroma is very floral, with big floral and citrus flavor and subtle earthy and spices hop notes; finishes with pronounced drying bitterness and a light-medium body.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# A pale golden ale with mild fruity and spicy characteristics and a crisp finish.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Name: beer_description, dtype: int64

# %%
def f(x):
    if x and type(x) is not float:
        if 'No notes at thi' in x:
            return None
        
        return x.split('Added')[0]

# %%
beer['beer_description'].apply(f)
# Out:
# 0                                        Duplicate listing
# 1                                                     None
# 2        19 Original Colonies Mead is brewed using 5 in...
# 3                                                     None
# 4        Single hop awesomeness, shining a spotlight on...
# 5        Duplicate of https://www.beeradvocate.com/beer...
# 6                                                     None
# 7                                                     None
# 8        Our American IPA gets its bold hop flavor from...
# 9                                                     None
# 10                                                    None
# 11                                                    None
# 12                                                    None
# 13       An altogether new and unique creation in the w...
# 14                                                    None
# 15                                                    None
# 16       **NOTE: This beer is now called "Brutal IPA" *...
# 17       A good solid stout packed with all the flavour...
# 18       Toasted, chocolaty dark malts align with an as...
# 19                                                    None
# 20       Brewed under the blood moon to usher in the ho...
# 21                                                    None
# 22                                                    None
# 23                                                    None
# 24                                                    None
# 25       "Special Brettanomyces yeast provides added dr...
# 26                                                    None
# 27                                                    None
# 28                                                    None
# 29                                                    None
#                                ...
# 19523    December  2011 - Zacks IIPA - designed by Home...
# 19524    Massive amounts of hops (3x the amount that go...
# 19525                                                 None
# 19526    Since our Double IPA is so huge, we decided to...
# 19527                                                 None
# 19528    Don't let the word 'accident' scare you.\r\r\r...
# 19529    A group of hop-heads and publicans challenged ...
# 19530                                                 None
# 19531    Intensely Hoppy, Pine, Citrus, Tropical Fruits...
# 19532    This is a big beer!...with 122 IBU's and weigh...
# 19533                                                 None
# 19534                                                 None
# 19535    Massive, pitch-black and complex brew made wit...
# 19536    This double IPA was brewed like Dragon Point, ...
# 19537    This is our tribute to the crazy world of big ...
# 19538    This hop megatron bomb blasts your palette in ...
# 19539    This IPA has 11 hop additions using 5 differen...
# 19540    Rye beers have been a part of our brewing arse...
# 19541    An Imperial IPA brewed with copious amounts of...
# 19542    This beer is an expression of our love for hop...
# 19543    Our hybrid IPA takes the classic West coast st...
# 19544    A True Hop Bomb Brewed plenty of Columbus and ...
# 19545    Ever since Stash Wojciechowski, the “Killer Ki...
# 19546    A mix of West Coast IPA and English yeast alon...
# 19547    Foothills' first high gravity beer. The high l...
# 19548    A True Hop Bomb Brewed plenty of Columbus and ...
# 19549    The world trembles with the beat: the marching...
# 19550    The world trembles with the beat: the marching...
# 19551                                                 None
# 19552    S.N.A.F.U is a double IPA, AKA DIPA, heavy hop...
# Name: beer_description, dtype: object

# %%
beer['beer_description'] = beer['beer_description'].apply(f)

# %%
beer.dropna(subset=['beer_description']).isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# name                    0
# abv                   182
# ibu                     0
# originalGravity      1049
# ogMin                1322
# isOrganic               0
# categoryId             70
# category_name          70
# styleId                70
# style_name             70
# style_description      74
# beer_description        0
# srmId                 989
# srmMin               1300
# srmMax               1330
# dtype: int64

# %%
beer_train = beer.dropna()
beer_train.shape
# Out:
# (15322, 17)

# %%
beer_train.head()
# Out:
#     Unnamed: 0      id                  name  abv  ibu  originalGravity  \
# 5            5  KgqNri  After Party Pale Ale  5.3    0            1.060
# 8            8  3D7Ba5          American IPA  5.0    0            1.060
# 16          16  4PXivT                Bitter  4.2    0            1.045
# 18          18  TbZRfB             Black IPA  6.5    0            1.056
# 20          20  k4ncgi            Blood Moon  9.4    0            1.080
#
#     ogMin isOrganic  categoryId               category_name  styleId  \
# 5   1.060         N         3.0  North American Origin Ales     30.0
# 8   1.060         N         3.0  North American Origin Ales     30.0
# 16  1.045         N         3.0  North American Origin Ales     36.0
# 18  1.056         N         3.0  North American Origin Ales     41.0
# 20  1.080         N         3.0  North American Origin Ales     33.0
#
#                        style_name  \
# 5   American-Style India Pale Ale
# 8   American-Style India Pale Ale
# 16           Golden or Blonde Ale
# 18       American-Style Black Ale
# 20               Imperial Red Ale
#
#                                     style_description  \
# 5   American-style India pale ales are perceived t...
# 8   American-style India pale ales are perceived t...
# 16  Golden or Blonde ales are straw to golden blon...
# 18  American-style Black Ales are very dark to bla...
# 20  Imperial Red Ales are deep amber to dark coppe...
#
#                                      beer_description  srmId  srmMin  srmMax
# 5   Duplicate of https://www.beeradvocate.com/beer...   10.0     6.0    14.0
# 8   Our American IPA gets its bold hop flavor from...   10.0     6.0    14.0
# 16  **NOTE: This beer is now called "Brutal IPA" *...    5.0     3.0     7.0
# 18  Toasted, chocolaty dark malts align with an as...   35.0    35.0    35.0
# 20  Brewed under the blood moon to usher in the ho...   12.5    10.0    15.0

# %%
import nltk
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.base import TransformerMixin, BaseEstimator

# %%
feature_cols = ['abv','ibu', 'originalGravity','srmId']
X1 = beer_train[feature_cols]
#X2 = beer_train['beer_description']
y = beer_train['styleId']

s = StandardScaler() 
X = s.fit_transform(X1.as_matrix())
knn = KNeighborsClassifier()

k_range = range(1, 30, 2)
param_grid = dict(n_neighbors=k_range)
grid = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid.fit(X, y)

grid.grid_scores_
grid_mean_scores = [result[1] for result in grid.grid_scores_]
#X_train, X_test, y_train, y_test = train_test_split(pd.merge, y, random_state=1)
#X = pd.concat(X1,X2)

# %%
print grid.grid_scores_
print grid_mean_scores
# Out:
# [mean: 0.43960, std: 0.10292, params: {'n_neighbors': 1}, mean: 0.47071, std: 0.10500, params: {'n_neighbors': 3}, mean: 0.49673, std: 0.10923, params: {'n_neighbors': 5}, mean: 0.50345, std: 0.10870, params: {'n_neighbors': 7}, mean: 0.50743, std: 0.10908, params: {'n_neighbors': 9}, mean: 0.50871, std: 0.10819, params: {'n_neighbors': 11}, mean: 0.51041, std: 0.10707, params: {'n_neighbors': 13}, mean: 0.51181, std: 0.10808, params: {'n_neighbors': 15}, mean: 0.51315, std: 0.10794, params: {'n_neighbors': 17}, mean: 0.51362, std: 0.10931, params: {'n_neighbors': 19}, mean: 0.51432, std: 0.10950, params: {'n_neighbors': 21}, mean: 0.51432, std: 0.10990, params: {'n_neighbors': 23}, mean: 0.51415, std: 0.11098, params: {'n_neighbors': 25}, mean: 0.51222, std: 0.11042, params: {'n_neighbors': 27}, mean: 0.51064, std: 0.10904, params: {'n_neighbors': 29}]
# [0.43960477081384469, 0.4707086061739944, 0.49672591206735267, 0.50344948550046775, 0.50742516370439661, 0.50871141253507957, 0.51040692235734331, 0.51181010289990647, 0.51315481758652948, 0.51362254443405053, 0.51432413470533211, 0.51432413470533211, 0.51414873713751175, 0.51221936389148737, 0.51064078578110383]

# %%
pipe = Pipeline([
        ('features', FeatureUnion([
                ('counts', CountVectorizer(max_features=50, stop_words='english')),
                ('tf_idf', TfidfVectorizer(max_features=50, stop_words='english'))
            ])),
                ('classifier', KNeighborsClassifier(k=3))
    ])
# Out:
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\ipykernel\__main__.py:9: DeprecationWarning: Passing additional arguments to the metric function as **kwargs is deprecated and will no longer be supported in 0.18. Use metric_params instead.

# %%
y = beer_train['styleId']
X = beer_train['beer_description']

# %%
scores = cross_val_score(pipe, X, y, cv=5, scoring='accuracy')

# %%
param_grid = {'classifier__n_neighbors':range(1,30),'features__counts__ngram_range': [(1, 1), (1, 2), (1,3)],'features__tf_idf__ngram_range':[(1, 1), (1, 2), (1,3)]}
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy')
grid.fit(X, y)

grid.grid_scores_
grid_mean_scores = [result[1] for result in grid.grid_scores_]

# %%
#print grid_mean_scores
print grid.grid_scores_
# Out:
# [mean: 0.16733, std: 0.01458, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.16645, std: 0.01267, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.16622, std: 0.01287, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.16558, std: 0.01287, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.16593, std: 0.01304, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.16610, std: 0.01317, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.16552, std: 0.01232, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.16604, std: 0.01279, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.16616, std: 0.01265, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 1, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.17610, std: 0.01429, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.17551, std: 0.01403, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.17534, std: 0.01352, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.17551, std: 0.01352, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.17657, std: 0.01337, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.17674, std: 0.01267, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.17686, std: 0.01272, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.17785, std: 0.01258, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.17750, std: 0.01214, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 2, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.19048, std: 0.01525, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.19159, std: 0.01524, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.19118, std: 0.01466, params: {'features__counts__ngram_range': (1, 1), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.19048, std: 0.01495, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.19048, std: 0.01399, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.19060, std: 0.01450, params: {'features__counts__ngram_range': (1, 2), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 3)}, mean: 0.18978, std: 0.01526, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 1)}, mean: 0.19083, std: 0.01490, params: {'features__counts__ngram_range': (1, 3), 'classifier__n_neighbors': 3, 'features__tf_idf__ngram_range': (1, 2)}, mean: 0.19072, std: 0.01433, params: {'features__counts__ngram_range': (1 ...

# %%
class TextTransform(BaseEstimator, TransformerMixin):
    def transform(self, X, **transform_params):
               
        return X['beer_description'].map(lambda x:x.lower())

    def fit(self, X, y=None, **fit_params):
        return self
    
class GetNumericFeatures(BaseEstimator, TransformerMixin):
    def transform(self, X, **transform_params):
        return X[['abv','ibu', 'originalGravity','srmId']]
    
    def fit(self, X, y=None, **fit_params):
        return self

# %%
t = TextTransform()
f = GetNumericFeatures()

# %%
print t.fit_transform(beer_train)
print f.fit_transform(beer_train).head()
# Out:
# <class 'pandas.core.series.Series'>
#     abv  ibu  originalGravity  srmId
# 5   5.3    0            1.060   10.0
# 8   5.0    0            1.060   10.0
# 16  4.2    0            1.045    5.0
# 18  6.5    0            1.056   35.0
# 20  9.4    0            1.080   12.5

# %%
vect = CountVectorizer(max_features = 50, stop_words = 'english')
tvect = t.fit_transform(beer_train)
vect.fit_transform(tvect)
# Out:
# <15322x50 sparse matrix of type '<type 'numpy.int64'>'
# 	with 111423 stored elements in Compressed Sparse Row format>

# %%
not_str_count = 0
str_count = 0

for index, row in beer_train.iterrows():
    if not type(row['beer_description']) == str:
        not_str_count += 1
    else:
        str_count += 1
        
print not_str_count
print str_count
# Out:
# 0
# 15322

# %%
pipe = Pipeline([
    ('features', FeatureUnion([
        ('textcount', Pipeline([
            ('text', TextTransform()),
            ('counts', CountVectorizer(max_features=50, stop_words='english'))
        ])),
        ('texttfidf', Pipeline([
            ('text', TextTransform()),    
            ('tf_idf', TfidfVectorizer(max_features=50, stop_words='english'))
        ])),
        ('scale_num', Pipeline([
            ('numeric', GetNumericFeatures()),
            ('scale', StandardScaler())
        ]))])),
    ('classifier', KNeighborsClassifier())
    ])
# Out:
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\ipykernel\__main__.py:15: DeprecationWarning: Passing additional arguments to the metric function as **kwargs is deprecated and will no longer be supported in 0.18. Use metric_params instead.

# %%
param_grid = {'classifier__n_neighbors':range(1,30),
              'features__textcount__counts__ngram_range': [(1, 1), (1, 2), (1,3)],
              'features__texttfidf__tf_idf__ngram_range':[(1, 1), (1, 2), (1,3)]}
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy')
grid.fit(beer_train.drop('styleId', axis=1),beer_train.styleId)

grid.grid_scores_
grid_mean_scores = [result[1] for result in grid.grid_scores_]

# %%
print grid_mean_scores
print grid.grid_scores_
# Out:
# [0.36881608145150763, 0.36972980028716879, 0.36972980028716879, 0.36796762824696516, 0.36783709698472783, 0.36783709698472783, 0.36796762824696516, 0.36783709698472783, 0.36783709698472783, 0.35824304921028588, 0.35798198668581127, 0.35798198668581127, 0.35589348649001434, 0.35569768959665837, 0.35569768959665837, 0.35589348649001434, 0.35569768959665837, 0.35569768959665837, 0.38591567680459471, 0.38552408301788277, 0.38552408301788277, 0.38500195796893355, 0.38480616107557758, 0.38480616107557758, 0.38500195796893355, 0.38480616107557758, 0.38480616107557758, 0.40321106905103771, 0.40347213157551232, 0.40347213157551232, 0.40308053778880043, 0.40223208458425791, 0.40223208458425791, 0.40308053778880043, 0.40223208458425791, 0.40223208458425791, 0.41880955488839577, 0.41828742983944656, 0.41828742983944656, 0.4195927424618196, 0.41796110168385331, 0.41796110168385331, 0.4195927424618196, 0.41796110168385331, 0.41796110168385331, 0.42853413392507506, 0.42755514945829526, 0.42755514945829526, 0.42846886829395642, 0.42775094635165123, 0.42775094635165123, 0.42846886829395642, 0.42775094635165123, 0.42775094635165123, 0.43284166557890613, 0.43290693121002483, 0.43290693121002483, 0.43290693121002483, 0.43271113431666886, 0.43271113431666886, 0.43290693121002483, 0.43271113431666886, 0.43271113431666886, 0.43656180655266935, 0.43695340033938129, 0.43695340033938129, 0.43551755645477092, 0.43479963451246573, 0.43479963451246573, 0.43551755645477092, 0.43479963451246573, 0.43479963451246573, 0.44126093199321237, 0.44184832267328022, 0.44184832267328022, 0.44060827568202582, 0.44099986946873776, 0.44099986946873776, 0.44060827568202582, 0.44099986946873776, 0.44099986946873776, 0.44485054170473831, 0.44543793238480617, 0.44543793238480617, 0.44576426054039942, 0.44458947918026365, 0.44458947918026365, 0.44576426054039942, 0.44458947918026365, 0.44458947918026365, 0.44837488578514556, 0.44817908889178959, 0.44817908889178959, 0.44889701083409478, 0.44824435452290823, 0.44824435452290823, 0.44889701083409478, 0.44824435452290823, 0.44824435452290823, 0.44968019840751861, 0.44968019840751861, 0.44968019840751861, 0.44968019840751861, 0.44850541704738284, 0.44850541704738284, 0.44968019840751861, 0.44850541704738284, 0.44850541704738284, 0.45157290170995956, 0.45157290170995956, 0.45157290170995956, 0.4506591828742984, 0.449419135883044, 0.449419135883044, 0.4506591828742984, 0.449419135883044, 0.449419135883044, 0.45457512074141759, 0.4535308706435191, 0.4535308706435191, 0.45294347996345125, 0.45111604229212898, 0.45111604229212898, 0.45294347996345125, 0.45111604229212898, 0.45111604229212898, 0.45561937083931603, 0.45477091763477351, 0.45477091763477351, 0.45457512074141759, 0.45242135491450203, 0.45242135491450203, 0.45457512074141759, 0.45242135491450203, 0.45242135491450203, 0.45431405821694298, 0.45477091763477351, 0.45477091763477351, 0.45555410520819739, 0.45444458947918026, 0.45444458947918026, 0.45555410520819739, 0.45444458947918026, 0.45444458947918026, 0.45444458947918026, 0.4538571987991124, 0.4538571987991124, 0.45248662054562067, 0.45209502675890878, 0.45209502675890878, 0.45248662054562067, 0.45209502675890878, 0.45209502675890878, 0.45379193316799371, 0.45411826132358701, 0.45411826132358701, 0.45405299569246832, 0.45300874559456988, 0.45300874559456988, 0.45405299569246832, 0.45300874559456988, 0.45300874559456988, 0.45607623025714661, 0.45659835530609583, 0.45659835530609583, 0.45705521472392641, 0.45516251142148545, 0.45516251142148545, 0.45705521472392641, 0.45516251142148545, 0.45516251142148545, 0.45679415219945174, 0.45725101161728232, 0.45725101161728232, 0.45829526171518081, 0.45679415219945174, 0.45679415219945174, 0.45829526171518081, 0.45679415219945174, 0.45679415219945174, 0.45666362093721447, 0.4567288865683331, 0.4567288865683331, 0.45796893355958751, 0.45679415219945174, 0.45679415219945174, 0.45796893355958751, 0.45679415219945174, 0.45679415219945174, 0.45601096462602791, 0.45574990210155331, 0.4557 ...
# [mean: 0.36882, std: 0.03609, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 1}, mean: 0.36973, std: 0.03638, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 1}, mean: 0.36973, std: 0.03638, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 1}, mean: 0.36797, std: 0.03595, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 1}, mean: 0.36784, std: 0.03617, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 1}, mean: 0.36784, std: 0.03617, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 1}, mean: 0.36797, std: 0.03595, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 1}, mean: 0.36784, std: 0.03617, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 1}, mean: 0.36784, std: 0.03617, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 1}, mean: 0.35824, std: 0.02919, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 2}, mean: 0.35798, std: 0.02905, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 2}, mean: 0.35798, std: 0.02905, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 2}, mean: 0.35589, std: 0.02794, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 2}, mean: 0.35570, std: 0.02759, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 2}, mean: 0.35570, std: 0.02759, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 2}, mean: 0.35589, std: 0.02794, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 2}, mean: 0.35570, std: 0.02759, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 2}, mean: 0.35570, std: 0.02759, params: {'features__textcount__counts__ngram_range': (1, 3), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 2}, mean: 0.38592, std: 0.03595, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 3}, mean: 0.38552, std: 0.03623, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 3}, mean: 0.38552, std: 0.03623, params: {'features__textcount__counts__ngram_range': (1, 1), 'features__texttfidf__tf_idf__ngram_range': (1, 3), 'classifier__n_neighbors': 3}, mean: 0.38500, std: 0.03621, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 1), 'classifier__n_neighbors': 3}, mean: 0.38481, std: 0.03575, params: {'features__textcount__counts__ngram_range': (1, 2), 'features__texttfidf__tf_idf__ngram_range': (1, 2), 'classifier__n_neighbors': 3}, mean: 0.38481, std:  ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipe_rf = Pipeline([
    ('features', FeatureUnion([
        ('textcount', Pipeline([
            ('text', TextTransform()),
            ('counts', CountVectorizer(max_features=50, stop_words='english'))
        ])),
        ('texttfidf', Pipeline([
            ('text', TextTransform()),    
            ('tf_idf', TfidfVectorizer(max_features=50, stop_words='english'))
        ])),
        ('numeric', GetNumericFeatures())
        ])),
    ('classifier', RandomForestClassifier())
    ])

# %%
param_grid_rf = {'classifier__n_estimators' :range(10,310,10),
              'features__textcount__counts__ngram_range': [(1, 1), (1, 2), (1,3)],
              'features__texttfidf__tf_idf__ngram_range':[(1, 1), (1, 2), (1,3)]}
grid = GridSearchCV(pipe_rf, param_grid_rf, cv=5, scoring='mean_squared_error')
grid.fit(beer_train.drop('styleId', axis=1),beer_train.styleId)

grid.grid_scores_
grid_mean_scores = [result[1] for result in grid.grid_scores_]
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-192-0bb70f43164c> in <module>()
#       3               'features__texttfidf__tf_idf__ngram_range':[(1, 1), (1, 2), (1,3)]}
#       4 grid = GridSearchCV(pipe_rf, param_grid_rf, cv=5, scoring='mean_squared_error')
# ----> 5 grid.fit(beer_train.drop('styleId', axis=1),beer_train.styleId)
#       6
#       7 grid.grid_scores_
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\grid_search.pyc in fit(self, X, y)
#     802
#     803         """
# --> 804         return self._fit(X, y, ParameterGrid(self.param_grid))
#     805
#     806
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     551                                     self.fit_params, return_parameters=True,
#     552                                     error_score=self.error_score)
# --> 553                 for parameters in parameter_iterable
#     554                 for train, test in cv)
#     555
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     798             # was dispatched. In particular this covers the edge
#     799             # case of Parallel used with an exhausted iterator.
# --> 800             while self.dispatch_one_batch(iterator):
#     801                 self._iterating = True
#     802             else:
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     656                 return False
#     657             else:
# --> 658                 self._dispatch(tasks)
#     659                 return True
#     660
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     564
#     565         if self._pool is None:
# --> 566             job = ImmediateComputeBatch(batch)
#     567             self._jobs.append(job)
#     568             self.n_dispatched_batches += 1
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, batch)
#     178         # Don't delay the application, to avoid keeping the input
#     179         # arguments in memory
# --> 180         self.results = batch()
#     181
#     182     def get(self):
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1529             estimator.fit(X_train, **fit_params)
#    1530         else:
# -> 1531             estimator.fit(X_train, y_train, **fit_params)
#    1532
#    1533     except Exception as e:
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\pipeline.pyc in fit(self, X, y, **fit_params)
#     163         """
#     164         Xt, fit_params = self._pre_transform(X, y, **fit_params)
# --> 165         self.steps[-1][-1].fit(Xt, y, **fit_params)
#     166         return self
#     167
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\ensemble\forest.pyc in fit(self, X, y, sample_weight)
#     288                     t, self, X, y, sample_weight, i, len(trees),
#     289                     verbose=self.verbose, class_weight=self.class_weight)
# --> 290                 for i, t in enumerate(trees))
#     291
#     292             # Collect newly grown trees
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     798             # was dispatched. In particular this covers the edge
#     799             # case of Parallel used with an exhausted iterator.
# --> 800             while self.dispatch_one_batch(iterator):
#     801                 self._iterating = True
#     802             else:
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     656                 return False
#     657             else:
# --> 658                 self._dispatch(tasks)
#     659                 return True
#     660
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     564
#     565         if self._pool is None:
# --> 566             job = ImmediateComputeBatch(batch)
#     567             self._jobs.append(job)
#     568             self.n_dispatched_batches += 1
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, batch)
#     178         # Don't delay the application, to avoid keeping the input
#     179         # arguments in memory
# --> 180         self.results = batch()
#     181
#     182     def get(self):
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\ensemble\forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     114             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     115
# --> 116         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     117     else:
#     118         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\sklearn\tree\tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            max_leaf_nodes)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
print grid_mean_scores
print grid.grid_scores_
# Out:
# [-377.18717632162907, -379.03979250750552, -381.29313095548889, -391.33737648479308, -369.94641365357006, -379.15006803942043, -394.52334616890738, -382.35756559195926, -386.83020365487533, -362.03288523038765, -361.12926906572244, -358.46627137449417, -363.53825553126222, -360.26743926217205, -362.21663661728229, -359.79082756820253, -360.17321433885917, -369.23254172921293, -356.82309386285516, -359.55786805247362, -357.12471172533321, -349.74200431913442, -352.52473423254867, -354.2954712497642, -350.22619738067272, -356.2495584446475, -354.29034568811733, -352.08707573994906, -351.56240558021153, -347.05763105134776, -353.63072549765053, -346.71601194116306, -349.38000137465735, -354.72380030674844, -348.8441910304627, -352.00978565068505]
# AttributeErrorTraceback (most recent call last)
# <ipython-input-193-6f835228ed65> in <module>()
#       1 print grid_mean_scores
# ----> 2 print grid.grid_scores_
#
# AttributeError: 'GridSearchCV' object has no attribute 'grid_scores_'

# %%
RMSE = []

for i in grid_mean_scores:
    RMSE.append(np.mean(np.sqrt(-i)))

RMSE
# Out:
# [19.421307276330012,
#  19.468944309014436,
#  19.526728629124975,
#  19.782249024941351,
#  19.233991100485881,
#  19.471776191180414,
#  19.862611766052002,
#  19.553965469744476,
#  19.667999482786126,
#  19.027161775482639,
#  19.003401513037669,
#  18.933205522956069,
#  19.066679195163015,
#  18.980712295964345,
#  19.031989822855682,
#  18.968152982517896,
#  18.978230010695391,
#  19.215424578426909,
#  18.88976161477045,
#  18.962011181635603,
#  18.897743561741258,
#  18.701390438123429,
#  18.775642045814269,
#  18.822738144323324,
#  18.714331336723539,
#  18.874574391086213,
#  18.822601990376285,
#  18.763983472065547,
#  18.749997482138806,
#  18.629482844441704,
#  18.805071802512494,
#  18.620311811061679,
#  18.691709428906105,
#  18.834112676384532,
#  18.677371095270949,
#  18.761923825948262]
