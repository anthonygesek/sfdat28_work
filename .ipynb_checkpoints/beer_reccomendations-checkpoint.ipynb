# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd
from pandas.io.json import json_normalize

# %%
brew_num = str(4)
r = requests.get('https://www.beeradvocate.com/beer/profile/'+brew_num)
b = BeautifulSoup(r.text, 'html.parser')
b.prettify()
# Out:
# u'<!DOCTYPE html>\n<html class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar Responsive pageIsLtr not_hasTabLinks hasSearch is-sidebarOpen hasRightSidebar is-setWidth navStyle_3 pageStyle_0 hasFlexbox" dir="LTR" id="XenForo" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <base href="https://www.beeradvocate.com/community/"/>\n  <script>\n   var _b = document.getElementsByTagName(\'base\')[0], _bH = "https://www.beeradvocate.com/community/";\n\t\t\tif (_b && _b.href != _bH) _b.href = _bH;\n  </script>\n  <title>\n   Allagash Brewing Company | Portland, ME | Beers | BeerAdvocate\n  </title>\n  <noscript>\n   <style>\n    .JsOnly, .jsOnly { display: none !important; }\n   </style>\n  </noscript>\n  <link href="css.php?css=xenforo,form,public&amp;style=7&amp;dir=LTR&amp;d=1477436989" rel="st
# ...

# %%
b.findAll('a')
# Out:
# [<a class="js-panelMask uix_panelMask" href="#"></a>,
#  <a class="navLink" href="/">Home</a>,
#  <a class="SplitCtrl" href="/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/about/">About</a>,
#  <a href="/contact/">Contact</a>,
#  <a href="/community/forums/help.32/">Help</a>,
#  <a href="/advertise/">Advertise</a>,
#  <a class="navLink" href="/mag/">Magazine</a>,
#  <a class="SplitCtrl" href="/mag/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/mag/category/magazine/culture/">Culture</a>,
#  <a href="/mag/category/magazine/food-drink/">Food &amp; Drink</a>,
#  <a href="/mag/category/magazine/news/">News</a>,
#  <a href="/mag/category/magazine/opinion/">Opinion</a>,
#  <a href="/mag/category/magazine/people-places/">People &amp; Places</a>,
#  <a href="/mag/category/magazine/science-technology/">Science &amp; Technology</a>,
#  <a href="/mag/category/magazine/travel/">Travel</a>,
# ...

# %%
reg_tag = re.compile("/beer/profile/\d+/\d+/")
reg2_tag = re.compile('\d.\d+')
reg3_tag = re.compile('\a+')
a_tag = b.findAll('a' , attrs={'href': reg_tag})
b_links={'Name':[], 'url':[] }
for a in a_tag:
    b_links['Name'].append(a.text)
for link in a_tag:
    b_links['url'].append(link.get('href'))

# %%
b_links
# Out:
# {'Name': [u'Allagash Astrid',
#   u'-',
#   u'Allagash Avanc\xe9',
#   u'-',
#   u'Allagash Black',
#   u'94',
#   u'Allagash Bourbon Barrel Black',
#   u'-',
#   u'Allagash Century Ale Brett Saison',
#   u'-',
#   u'Allagash Confluence Ale',
#   u'92',
#   u'Allagash Coolship Cerise',
#   u'100',
#   u'Allagash Coolship Red',
#   u'100',
#   u'Allagash Coolship Resurgam',
#   u'100',
#   u'Allagash Curieux (Bourbon Barrel-Aged Tripel)',
#   u'99',
#   u'Allagash Dougernaut',
#   u'-',
#   u'Allagash Dubbel Ale',
#   u'89',
#   u'Allagash Emile',
#   u'-',
#   u'Allagash Evora',
#   u'-',
#   u'Allagash Farm To Face',
#   u'-',
#   u'Allagash Fluxus 2016',
#   u'-',
#   u'Allagash Four',
#   u'-',
#   u'Allagash FV 13',
#   u'-',
#   u'Allagash Ghoulschip',
#   u'-',
#   u'Allagash Golden Brett',
#   u'-',
#   u'Allagash Grand Cru',
#   u'92',
#   u'Allagash Helena',
#   u'-',
#   u'Allagash Hibernal Fluxus 2016',
#   u'-',
#   u'Allagash Hive 56',
#   u'-',
# ...

# %%
#def get_beer_rating(brew_num):
    #search = requests.get('https://www.beeradvocate.com/beer/profile/'+brew_num)
    #soup = BeautifulSoup(search.text, 'html.parser')
    #b_name = re.compile()
    #b_style = re.compile()
    #b_rating = re.complie()
    #b_abv = re.compile()

# %%
API_key = '209db383ed1d39ec3aa1c13f89161c25'
r= requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p=2&ibu=100')

# %%
r.json()
# Out:
# {u'currentPage': 2,
#  u'data': [{u'abv': u'9.75',
#    u'available': {u'description': u'Available at the same time of year, every year.',
#     u'id': 4,
#     u'name': u'Seasonal'},
#    u'availableId': 4,
#    u'createDate': u'2014-08-09 01:42:10',
#    u'description': u'Caf\xe9 Racer 15\u2122 features aromas of bright citrus and resinous pine from the generous use of Citra, Amarillo, Cascade and Chinook hops which are complimented by a dry malt finish. The result is a high revving Double IPA that is loud and assertive, much like the rebellious street racers who inspired it. Never ride alone\u2026',
#    u'glass': {u'createDate': u'2012-01-03 02:41:33',
#     u'id': 5,
#     u'name': u'Pint'},
#    u'glasswareId': 5,
#    u'ibu': u'100',
#    u'id': u'4bk3v2',
#    u'isOrganic': u'N',
#    u'labels': {u'icon': u'https://s3.amazonaws.com/brewerydbapi/beer/4bk3v2/upload_6cYlSR-icon.png',
#     u'large': u'https://s3.amazonaws.com/brewerydbapi/beer/4bk3v2/upload_6cYlSR-large.png',
# ...

# %%
#df = pd.DataFrame(r.json())
#beers = json_normalize(df['data'])
#beers.head()

# %%
rows = []

def parse_beer(beer):
    return [beer.get('id'),
            beer.get('name'), 
            beer.get('abv'), 
            beer.get('ibu', 0),
            beer.get('originalGravity'),
            beer.get('isOrganic'),
            beer.get('style', {}).get('categoryId'),
            beer.get('style', {}).get('category', {}).get('name'),
            beer.get('styleId'),
            beer.get('style', {}).get('name'),
            beer.get('style', {}).get('description'),
            beer.get('servingTemperatureDisplay'),
            beer.get('foodPairings'),
            beer.get('description'),
            beer.get('labels', {}).get('medium'),
            beer.get('glasswareID'),
            beer.get('glass', {}).get('name')
            beer.get('srmID')
            beer.get('srm', {}).get('hex')
           ]


ibus = range(74,150)
for ibu in ibus:
    if ibu % 2 == 0:
        print ibu
        pd.DataFrame(rows).to_csv('saved_beers.csv', encoding='utf-8')
    r = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p=1&ibu='+str(ibu))
    response = r.json()
    rows += [parse_beer(r) for r in response['data']]
    if response['numberOfPages'] > 1:
        page = range(2,response['numberOfPages']+1)
        for p in page:
            response = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p='+str(p)+'&ibu='+str(ibu)).json()
            rows += [parse_beer(r) for r in response['data']]
# Out:
# 74
# 76
# 78
# 80
# 82
# 84
# 86
# 88
# 90
# 92
# 94
# 96
# 98
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 128
# KeyErrorTraceback (most recent call last)
# <ipython-input-77-bfcc6f9650f1> in <module>()
#      27     r = requests.get('http://api.brewerydb.com/v2/beers/?key=209db383ed1d39ec3aa1c13f89161c25&p=1&ibu='+str(ibu))
#      28     response = r.json()
# ---> 29     rows += [parse_beer(r) for r in response['data']]
#      30     if response['numberOfPages'] > 1:
#      31         page = range(2,response['numberOfPages']+1)
#
# KeyError: 'data'

# %%
response
# Out:
# {u'currentPage': 1, u'status': u'success'}

# %%
pd.DataFrame(rows).shape
# Out:
# (2386, 15)

# %%
#beers=pd.DataFrame(rows)
#beers.columns = ['id', 
                 #'name', 
                 #'abv',
                 #'ibu',
                 #'original_gravity',
                 #'is_organic',
                 #'category_id',
                 #'category_name',
                 #'style_id',
                 #'style_name',
                 #'style_description',
                 #'seriving_temp',
                 #'food_pairing',
                 #'description',
                 #'label']
#beers.shape
# Out:
# (2386, 15)

# %%
beer_list = pd.read_csv('.\data\saved_beers_1.csv')
beer_list.columns = ['unknown',
                     'id', 
                     'name', 
                     'abv',
                     'ibu',
                     'original_gravity',
                     'is_organic',
                     'category_id',
                     'category_name',
                     'style_id',
                     'style_name',
                     'style_description',
                     'seriving_temp',
                     'food_pairing',
                     'description',
                     'label']
del beer_list['unknown']
beer_list.head()
# Out:
#        id                      name  abv  ibu  original_gravity  is_organic  \
# 0  njehqH                   144 IPA  NaN    0               NaN         NaN
# 1  EVVV1r          1488 Whisky Beer  7.0    0               NaN         NaN
# 2  295GZo      19 Original Colonies  5.5    0             1.008         NaN
# 3  Np1soi  666 Premium British Beer  6.6    0               NaN         NaN
# 4  7xU7NH             Ace of Simcoe  4.5    0               NaN         NaN
#
#    category_id               category_name  style_id  \
# 0          3.0  North American Origin Ales      30.0
# 1         11.0           Hybrid/mixed Beer     138.0
# 2         12.0        Mead, Cider, & Perry     148.0
# 3          1.0         British Origin Ales       3.0
# 4          3.0  North American Origin Ales     164.0
#
#                       style_name  \
# 0  American-Style India Pale Ale
# 1      Other Strong Ale or Lager
# 2             Open Category Mead
# 3                Ordinary Bitter
# ...

# %%
beer_list2 = pd.concat([beer_list,beers], axis = 0)
beer_list2.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-619c1aac6bbd> in <module>()
# ----> 1 beer_list2 = pd.concat([beer_list,beers], axis = 0)
#       2 beer_list2.shape
#
# NameError: name 'beer_list' is not defined

# %%
beer_list2.to_csv('beer_list2.csv', encoding='utf-8')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-5c6b07bb33ec> in <module>()
# ----> 1 beer_list2.to_csv('beer_list2.csv', encoding='utf-8')
#
# NameError: name 'beer_list2' is not defined

# %%
beer_list2.head()
# Out:
#        id                      name  abv ibu original_gravity is_organic  \
# 0  njehqH                   144 IPA  NaN   0              NaN        NaN
# 1  EVVV1r          1488 Whisky Beer    7   0              NaN        NaN
# 2  295GZo      19 Original Colonies  5.5   0            1.008        NaN
# 3  Np1soi  666 Premium British Beer  6.6   0              NaN        NaN
# 4  7xU7NH             Ace of Simcoe  4.5   0              NaN        NaN
#
#    category_id               category_name  style_id  \
# 0          3.0  North American Origin Ales      30.0
# 1         11.0           Hybrid/mixed Beer     138.0
# 2         12.0        Mead, Cider, & Perry     148.0
# 3          1.0         British Origin Ales       3.0
# 4          3.0  North American Origin Ales     164.0
#
#                       style_name  \
# 0  American-Style India Pale Ale
# 1      Other Strong Ale or Lager
# 2             Open Category Mead
# 3                Ordinary Bitter
# ...

# %%
beer_list2['brewery_id','brewery_name', 'brewery_description']=[None]*beer_list2.shape[0]
rows = {'brewery_id':[],
        'brewery_name':[],
        'brewery_description':[],
        'brewery_established':[],
        'isOrganic2':[],
        'glassware_id':[],
        'glassware_name':[],
        'srm_id':[],
        'srm_hex':[]}
for c in beer_list2['id'][:3]:
    beer2 = api.get_beer(c)
    d = beer2.__dict__['data']
    rows['isOrganic2'].append(d.get('isOrganic'))
    rows['glassware_id'].append(d.get('glasswareID'))
    rows['glassware_name'].append(d.get('glass', {}).get('name'))
    rows['srm_id'].append(d.get('srmID'))
    rows['srm_hex'].append(d.get('srm', {}).get('hex'))
    breweries = d.get('breweries', [{}])
    brewery = breweries[0]
    rows['brewery_id'].append(brewery.get('id'))
    rows['brewery_name'].append(brewery.get('name'))
    rows['brewery_description'].append(brewery.get('description'))
    rows['brewery_established'].append(brewery.get('established'))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-fa79001601bf> in <module>()
# ----> 1 beer_list2['brewery_id','brewery_name', 'brewery_description']=[None]*beer_list2.shape[0]
#       2 rows = {'brewery_id':[],
#       3         'brewery_name':[],
#       4         'brewery_description':[],
#       5         'brewery_established':[],
#
# NameError: name 'beer_list2' is not defined

# %%
beer_list3 = beer_list2.head(3)

# %%
for new_col, col in rows.iteritems():
    beer_list3[new_col] = col
beer_list3
# Out:
# C:\Users\antho\Anaconda2\envs\data28\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        id                  name  abv ibu original_gravity is_organic  \
# 0  njehqH               144 IPA  NaN   0              NaN        NaN
# 1  EVVV1r      1488 Whisky Beer    7   0              NaN        NaN
# 2  295GZo  19 Original Colonies  5.5   0            1.008        NaN
#
#    category_id               category_name  style_id  \
# 0          3.0  North American Origin Ales      30.0
# 1         11.0           Hybrid/mixed Beer     138.0
# 2         12.0        Mead, Cider, & Perry     148.0
#
#                       style_name  \
# 0  American-Style India Pale Ale
# ...

# %%
from brewerydb import *
#dir(brewerydb)

# %%
api = BreweryDB('209db383ed1d39ec3aa1c13f89161c25')
#beer = api.search_beer('stella artois')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-57614eec090b> in <module>()
#       1
# ----> 2 api = BreweryDB('209db383ed1d39ec3aa1c13f89161c25')
#       3 #beer = api.search_beer('stella artois')
#
# NameError: name 'BreweryDB' is not defined

# %%
beer = api.get_beer('7xU7NH')
beer.__dict__
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-9f5303924569> in <module>()
# ----> 1 beer = api.get_beer('7xU7NH')
#       2 beer.__dict__
#
# NameError: name 'api' is not defined

# %%
# -*- coding: utf-8 -*-

__author__ = 'Derek Stegelman'

import json
import requests
import urllib

from .beer import Beer, Beers
from .brewery import Brewery, Breweries


BASE_URL = 'http://api.brewerydb.com/v2'


class BreweryDB(object):
    def __init__(self, api_key):
        self.api_key = api_key
        
    def _auth(self):
        return "key=%s" % self.api_key
        
    def _call(self, resource_url, params=None):
        url = "%s/%s" % (BASE_URL, resource_url)
        
        if params:
            url += "?%s&%s" % (params, self._auth())
        else:
            url += "?%s" % self._auth()
        
        return requests.get(url)
    
    def _params(self, params):
        """
        Takes dictionary of parameters and returns
        urlencoded string

        :param params: Dict of query params to encode
        :type params: dict
        
        :returns:  str -- URL encoded query parameters
        """
        return urllib.urlencode(params)
    
    def search_beer(self, beer_name):
        """ Search the BreweryDB for a beer.  Returns a
        list of Beer objects.
        
        get /beers/
        
        :param beer_name: Query of the beer to search for
        :type params: string
        
        :returns:  List of Beer objects
        
        """
        response = json.loads(self._call("search", self._params(params={'q': beer_name, 'withBreweries': 'Y', 'type': 'beer'})).text)
        beers = []
        for beer in response['data']:
            beers.append(Beers(beer))
        return beers
        
    def get_beer(self, id):
        """Fetches a single beer by id.

        get /beer/<id>/

        :param id: ID of beer
        :type params: int
        
        :returns:  Beer object
        """        
        response = json.loads(self._call("%s/%s" % (Beer.resource_url, id), self._params({'withBreweries': 'Y'})).text)
        return Beer(response['data'])
        
    def search_breweries(self, brewery_name):
        """Fetches a single brewery by id.

        get /breweries/

        :param brewery_name: Search query for breweries
        :type params: string
        
        :returns:  List of brewery objects

        """
        response = json.loads(self._call('search', self._params(params={'q': brewery_name, 'type': 'brewery'})).text)
        breweries = []
        for brewery in response['data']:
            breweries.append(Brewery(brewery))
        return breweries
    
    def get_brewery(self, id):
        """Fetches a single character by id.

        get /brewery/<id>/

        :param id: ID of Brewery
        :type params: int
        
        :returns:  Brewery object
        """
        response = json.loads(self._call("%s/%s" % (Brewery.resource_url, id)).text)
        return Brewery(response['data'])
